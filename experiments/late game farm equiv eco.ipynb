# %%
import b2sim.engine as b2
import b2sim.analysis as dd

# %%
rounds = b2.Rounds(0.1)

farms = [
    b2.initFarm(rounds.getTimeFromRound(20), upgrades = [5,2,0]),
    b2.initFarm(rounds.getTimeFromRound(20), upgrades = [4,2,0])
]

initial_state_game = {
    'Cash': 0,
    'Eco': 0,
    'Eco Send': b2.ecoSend(send_name = 'Zero'),
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 41
}


game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 50)
dd.viewHistory(game_state)
print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'late_game_farm_eco_impact')
# Out:
#      Time   Type             Message
# 0  1202.1    Eco  Change eco to Zero
# 1  1244.2  Round      Round 42 start
# 2  1275.7  Round      Round 43 start
# 3  1303.1  Round      Round 44 start
# 4  1324.1  Round      Round 45 start
# 5  1342.5  Round      Round 46 start
# 6  1383.9  Round      Round 47 start
# 7  1405.4  Round      Round 48 start
# 8  1444.0  Round      Round 49 start
# 9  1480.4  Round      Round 50 start
#              Revenue  Expenses    Profit  Eco Impact  Start Time  End Time
# Farm Index
# 0           157500.0         0  157500.0      3396.0      1202.0    1480.0
# 1            42188.0         0   42188.0       910.0      1202.0    1480.0
# The current cash and eco are (199687.5,0)

# %%
initial_state_game = {
    'Cash': 0,
    'Eco': 0,
    'Eco Send': b2.ecoSend(send_name = 'Grouped Yellows'),
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 3
}
game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 4)
dd.viewHistory(game_state)
print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'late_game_farm_eco_impact')
# Out:
# [{'Time': 156.85, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]
# None
# None
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       1 initial_state_game = {
#       2     'Cash': 0,
#       3     'Eco': 0,
#    (...)
#       7     'Game Round': 3
#       8 }
#       9 game_state = b2.GameState(initial_state_game)
# ---> 10 game_state.fastForward(target_round = 4)
#      11 dd.viewHistory(game_state)
#      12 print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
#
# File c:\Program Files\Python312\Lib\site-packages\b2sim\engine\main.py:623, in GameState.fastForward(self, target_time, target_round, interval)
#     621     intermediate_time = min(max(floor(self.current_time/interval + 1)*interval,self.current_time + interval/2),target_time)
#     622     self.logs.append("Advancing game to time %s"%(round(intermediate_time,3)))
# --> 623     self.advanceGameState(target_time = intermediate_time)
#     624     #self.logs.append("----------")
#     625
#     626 # Sort the messages in self.event_messages so that they are listed chronologically
#     627 self.event_messages = sorted(self.event_messages, key=lambda x: x['Time'])
#
# File c:\Program Files\Python312\Lib\site-packages\b2sim\engine\main.py:702, in GameState.advanceGameState(self, target_time, target_round)
#     696 payout = payout_times[i]
#     698 #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     699 #First, compute the impact of eco from the previous payout (or starting time) to the current one
#     700 #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# --> 702 self.updateEco(payout['Time'])
#     704 if (self.max_send_amount is not None and self.number_of_sends >= self.max_send_amount) or (self.max_eco_amount is not None and self.eco >= self.max_eco_amount) or (self.max_send_time is not None and self.current_time > self.max_send_time):
#     705     self.logs.append("Reached the limit on eco'ing for this send! Moving to the next send in the queue.")
#
# File c:\Program Files\Python312\Lib\site-packages\b2sim\engine\main.py:1097, in GameState.updateEco(self, target_time)
#    1093     self.attack_queue.pop(0)
#    1095 # Next, try to add an attack to the attack_queue.
#    1096 # Can we send an attack?
# -> 1097 if self.cash >= max(self.eco_cost, self.save) and len(self.attack_queue) < min(6, self.attack_queue_threshold):
#    1098     # Yes, the queue is empty and we have enough cash
#    1099     if len(self.attack_queue) == 0:
#    1100         self.attack_queue.append(self.current_time + self.eco_time)
#
# AttributeError: 'GameState' object has no attribute 'eco_cost'

# %%
game_state.logs
# Out:
# ['MESSAGE FROM GameState.__init__(): ',
#  'Initialized Game State!',
#  'The current game round is 3',
#  'The current game time is 52.849999999999994 seconds',
#  'The game round start times are given by [0, 6.0, 29.849999999999998, 52.849999999999994, 76.94999999999999, 106.14999999999999, 133.45, 156.85, 180.35, 201.6, 222.29999999999998, 233.85, 248.4, 266.15, 284.95, 297.05, 313.35, 346.40000000000003, 385.65000000000003, 411.8, 448.15000000000003, 456.95000000000005, 473.50000000000006, 503.75000000000006, 516.3000000000001, 576.7500000000001, 614.4000000000001, 643.1500000000001, 668.3000000000001, 692.5500000000001, 739.3000000000001, 749.1, 803.844, 819.8240000000001, 849.0240000000001, 863.9156600000001, 911.5076600000001, 939.6556600000001, 1028.4906600000002, 1093.8614900000002, 1190.3114900000003, 1202.1114900000002, 1244.2414900000003, 1275.6914900000004, 1303.1414900000004, 1324.1414900000004, 1342.4914900000003, 1383.9414900000004, 1405.3914900000004, 1443.9614900000004, 1480.4114900000004, 1491.3114900000005] \n',
#  'MESSAGE FROM GameState.fastForward: ',
#  'Advancing game to time 52.9',
#  'Warning! Time 0 is too early to call Grouped Yellows. Adjusting the queue time to 156.85',
#  'self.changeNow returned False!']

# %%
from scipy.stats import norm

# %%
1 - norm.cdf((90-110)/22)
# Out:
# 0.818348929556551

# %%
norm.cdf(-0.91)
# Out:
# 0.1814112548917972
