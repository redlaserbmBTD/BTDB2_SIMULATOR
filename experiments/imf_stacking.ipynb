# %%
import b2sim as b2

# %%
rounds = b2.Rounds(0.1)

farms = [
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0])
]

buy_queue = [
    [b2.activateIMF(i) for i in range(len(farms))],
    [b2.activateIMF(i) for i in range(len(farms))],
    [b2.activateIMF(i) for i in range(len(farms))],
    [b2.activateIMF(i) for i in range(len(farms))],
    [b2.activateIMF(i) for i in range(len(farms))]
]

initial_state_game = {
    'Cash': 0,
    'Eco': 700,
    'Loan': 69000,
    'Eco Send': b2.ecoSend(send_name = 'Zero'),
    'Buy Queue': buy_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 24.5
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 30)
game_state.viewCashEcoHistory()
print("The current cash and eco and debt are (%s,%s, %s)"%(game_state.cash, game_state.eco, game_state.loan))
b2.writeLog(game_state.logs, filename = 'imf_test')
# Out:
#     Time   Type                                            Message
# 0  546.5    Eco                                 Change eco to Zero
# 1  546.6    Buy  Take out loan from farm 0, Take out loan from ...
# 2  576.8  Round                                     Round 25 start
# 3  614.4  Round                                     Round 26 start
# 4  636.6    Buy  Take out loan from farm 0, Take out loan from ...
# 5  643.2  Round                                     Round 27 start
# 6  668.3  Round                                     Round 28 start
# 7  692.6  Round                                     Round 29 start
# 8  726.6    Buy  Take out loan from farm 0, Take out loan from ...
# 9  739.3  Round                                     Round 30 start
#             Revenue  Expenses   Profit  Eco Impact  Start Time  End Time
# Farm Index
# 0           30000.0         0  30000.0       934.0       547.0     739.0
# 1           30000.0         0  30000.0       934.0       547.0     739.0
# ...

# %%
rounds = b2.Rounds(0.1)

farms = [
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,4,0]),
    b2.initFarm(rounds.getTimeFromRound(24), upgrades = [2,0,5])
]

buy_queue = [
    [b2.activateIMF(i) for i in range(len(farms)-1)],
    [b2.activateIMF(i) for i in range(len(farms)-1)],
    [b2.activateIMF(i) for i in range(len(farms)-1)],
    [b2.activateIMF(i) for i in range(len(farms)-1)],
    [b2.activateIMF(i) for i in range(len(farms)-1)]
]

initial_state_game = {
    'Cash': 0,
    'Eco': 700,
    'Loan': 69000,
    'Eco Send': b2.ecoSend(send_name = 'Zero'),
    'Buy Queue': buy_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 24.5
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 30)
game_state.viewCashEcoHistory()
print("The current cash and eco and debt are (%s,%s, %s)"%(game_state.cash, game_state.eco, game_state.loan))
b2.writeLog(game_state.logs, filename = 'imf_test')
# Out:
#     Time   Type                                            Message
# 0  546.5    Eco                                 Change eco to Zero
# 1  546.6    Buy  Take out loan from farm 0, Take out loan from ...
# 2  576.8  Round                                     Round 25 start
# 3  614.4  Round                                     Round 26 start
# 4  636.6    Buy  Take out loan from farm 0, Take out loan from ...
# 5  643.2  Round                                     Round 27 start
# 6  668.3  Round                                     Round 28 start
# 7  692.6  Round                                     Round 29 start
# 8  726.6    Buy  Take out loan from farm 0, Take out loan from ...
# 9  739.3  Round                                     Round 30 start
#             Revenue  Expenses   Profit  Eco Impact  Start Time  End Time
# Farm Index
# 0           30000.0         0  30000.0       934.0       547.0     739.0
# 1           30000.0         0  30000.0       934.0       547.0     739.0
# ...

# %%
rounds = b2.Rounds(0.1)

farms = [
    b2.initFarm(rounds.getTimeFromRound(13.99), upgrades = [2,4,0]),
]

buy_queue = [
    [b2.activateIMF(0)],
    [b2.buyFarm(upgrades=(2,4,0))],
    [b2.activateIMF(1)],
    [b2.activateIMF(0)]
]

initial_state_game = {
    'Cash': 0,
    'Eco': 600,
    'Loan': 0,
    'Eco Send': b2.ecoSend(send_name = 'Zero'),
    'Buy Queue': buy_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 14
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_time = 335)
game_state.viewCashEcoHistory()
print("The current cash and eco and debt are (%s,%s, %s)"%(game_state.cash, game_state.eco, game_state.loan))
b2.writeLog(game_state.logs, filename = 'imf_snowball')
# Out:
#     Time   Type                              Message
# 0  285.0    Eco                   Change eco to Zero
# 1  297.0  Round                       Round 15 start
# 2  309.8    Buy  Take out loan from farm 0, Buy Farm
# 3  313.4  Round                       Round 16 start
# 4  334.8    Buy            Take out loan from farm 1
#             Revenue  Expenses   Profit  Eco Impact  Start Time  End Time
# Farm Index
# 0           20000.0         0  20000.0      2398.0       285.0     335.0
# 1           10000.0     15600  -5600.0      2381.0       310.0     335.0
# The current cash and eco and debt are (18000.0,600, 28800.0)
