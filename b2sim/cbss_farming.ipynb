# %%
import b2sim as b2

# %%
rounds = b2.Rounds([(0,0.25), (20,0.0)])

buy_queue = [
    [b2.buyDefense(-4250), b2.buySupplyDrop()], #Buy the supply drop, assuming we already have a 230 sniper on screen
    [b2.buyEliteSniper(0)], #Update the sniper farm at index 0 to an elite sniper
    [b2.repeatedlyBuySupplyDrops(max_buy_time = rounds.getTimeFromRound(26))] #Repeatedly buy supply drops until the specified end time
]

eco_queue = [
    b2.ecoSend(rounds.getTimeFromRound(19.2), 'Zero'),
    b2.ecoSend(rounds.getTimeFromRound(20), 'Grouped Pinks')
]

initial_state_game = {
    'Cash': 0,
    'Eco': 850,
    'Eco Send': b2.ecoSend(send_name = 'Grouped Blacks'),
    'Rounds': rounds,
    'Game Round': 13,
    'Buy Queue': buy_queue,
    'Eco Queue': eco_queue
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 26)
game_state.viewCashEcoHistory((24,12))
print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
b2.writeLog(game_state.logs, filename = 'cbss_farming_2')
# Out:
# The current cash and eco are (6796.400000000819,3989.800000000065)
# We currently have 9 supply drops on screen
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 29
#      27 print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
#      28 print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
# ---> 29 b2.writeLog(game_state.logs, filename = 'cbss_farming_2')
#
# File ~/.local/lib/python3.10/site-packages/b2sim/main.py:27, in writeLog(lines, filename, path)
#      26 def writeLog(lines, filename = 'log', path = 'logs/'):
# ---> 27     with open(path + filename + '.txt', 'w') as f:
#      28         for line in lines:
#      29             f.write(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/cbss_farming_2.txt'

# %%
rounds = b2.Rounds([(0,0.25), (20,0.0)])

buy_queue = [
    [b2.buyDefense(-4250), b2.buySupplyDrop()], #Buy the supply drop, assuming we already have a 230 sniper on screen
    [b2.buyEliteSniper(0)], #Update the sniper farm at index 0 to an elite sniper
    [b2.repeatedlyBuySupplyDrops(max_buy_time = rounds.getTimeFromRound(26))] #Repeatedly buy supply drops until the specified end time
]

eco_queue = [
    b2.ecoSend(rounds.getTimeFromRound(18.5), 'Zero'),
    b2.ecoSend(rounds.getTimeFromRound(19.7), 'Grouped Pinks')
]

initial_state_game = {
    'Cash': 0,
    'Eco': 850,
    'Eco Send': b2.ecoSend(send_name = 'Grouped Blacks'),
    'Rounds': rounds,
    'Game Round': 13,
    'Buy Queue': buy_queue,
    'Eco Queue': eco_queue
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 26)
game_state.viewCashEcoHistory((24,12))
print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
b2.writeLog(game_state.logs, filename = 'cbss_farming_3')
# Out:
# The current cash and eco are (4897.200000000968,3900.4000000000688)
# We currently have 9 supply drops on screen
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 29
#      27 print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
#      28 print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
# ---> 29 b2.writeLog(game_state.logs, filename = 'cbss_farming_3')
#
# File ~/.local/lib/python3.10/site-packages/b2sim/main.py:27, in writeLog(lines, filename, path)
#      26 def writeLog(lines, filename = 'log', path = 'logs/'):
# ---> 27     with open(path + filename + '.txt', 'w') as f:
#      28         for line in lines:
#      29             f.write(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/cbss_farming_3.txt'

# %%
rounds = b2.Rounds([(0,0.20), (20,0.0)])

buy_queue = [
    [b2.buyDefense(-4250), b2.buySupplyDrop()], #Buy the supply drop, assuming we already have a 230 sniper on screen
    [b2.buyEliteSniper(0)], #Update the sniper farm at index 0 to an elite sniper
    [b2.repeatedlyBuySupplyDrops(max_buy_time = rounds.getTimeFromRound(26))] #Repeatedly buy supply drops until the specified end time
]

eco_queue = [
    b2.ecoSend(rounds.getTimeFromRound(17.5), 'Zero'),
    b2.ecoSend(rounds.getTimeFromRound(19.0), 'Grouped Pinks')
]

initial_state_game = {
    'Cash': 0,
    'Eco': 850,
    'Eco Send': b2.ecoSend(send_name = 'Grouped Yellows'),
    'Rounds': rounds,
    'Game Round': 13,
    'Buy Queue': buy_queue,
    'Eco Queue': eco_queue
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 26)
game_state.viewCashEcoHistory((24,12))
print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
b2.writeLog(game_state.logs, filename = 'cbss_farming_4')
# Out:
# The current cash and eco are (42.79999999998836,3715.600000000053)
# We currently have 9 supply drops on screen
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 29
#      27 print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
#      28 print("We currently have %s supply drops on screen"%(len(game_state.supply_drops)))
# ---> 29 b2.writeLog(game_state.logs, filename = 'cbss_farming_4')
#
# File ~/.local/lib/python3.10/site-packages/b2sim/main.py:27, in writeLog(lines, filename, path)
#      26 def writeLog(lines, filename = 'log', path = 'logs/'):
# ---> 27     with open(path + filename + '.txt', 'w') as f:
#      28         for line in lines:
#      29             f.write(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/cbss_farming_4.txt'
